# %%
#import pandas

import pandas as pd

# %%
#read csv

df = pd.read_csv("titanic.csv")

# %%
#describe data

df.describe(titanic.Age.fillna(titanic.Age.mean(), inplace=True)
)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#              Fare  ek aur column
# count  891.000000     891.000000
# mean    32.204208       2.308642
# std     49.693429       0.836071
# min      0.000000       1.000000
# 25%      7.910400       2.000000
# 50%     14.454200       3.000000
# 75%     31.000000       3.000000
# max    512.329200       3.000000

# %%
#check head

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#check tail

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#get shape

df.shape
# Out:
# (891, 12)

# %%
#get colums

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#get info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## Column operations

# %%
#get columns by name

df['Name'].head() 

# OR 
# df.Name
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#save column to a variable

Names = df['Name']

#check type
print(type(Names))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#convert dataframe to array

print(type(Names.values))
# Out:
# <class 'numpy.ndarray'>

# %%
# subset multiple columns

df[['Name', 'Fare', 'Cabin']].head()
# Out:
#                                                 Name     Fare Cabin
# 0                            Braund, Mr. Owen Harris   7.2500   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833   C85
# 2                             Heikkinen, Miss. Laina   7.9250   NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123
# 4                           Allen, Mr. William Henry   8.0500   NaN

# %%
#delete a column completely

del df['Parch']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# ## Rows

# %%
#get value of a row

#first row
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
#last row
df.iloc[-1]
# Out:
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                             32
# SibSp                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object

# %%
#multiple rows

df.iloc[[0, 10, 100]]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 0              1         0       3          Braund, Mr. Owen Harris    male
# 10            11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 100          101         0       3          Petranec, Miss. Matilda  female
#
#       Age  SibSp     Ticket     Fare Cabin Embarked
# 0    22.0      1  A/5 21171   7.2500   NaN        S
# 10    4.0      1    PP 9549  16.7000    G6        S
# 100  28.0      0     349245   7.8958   NaN        S

# %%
#particular data

df.iloc[[0, 10, 100], [3,4,5]]
# Out:
#                                 Name     Sex   Age
# 0            Braund, Mr. Owen Harris    male  22.0
# 10   Sandstrom, Miss. Marguerite Rut  female   4.0
# 100          Petranec, Miss. Matilda  female  28.0

# %% [markdown]
# ## Operations

# %%
#get unique data

print(df['Sex'].unique())
# Out:
# ['male' 'female']

# %%
print(df['Pclass'].unique())
# Out:
# [3 1 2]

# %%
#get mean

df['Age'].mean()
# Out:
# 29.699117647058763

# %%
#add new columns

df['New Column'] = 'New Value'
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#              Ticket     Fare Cabin Embarked New Column
# 0         A/5 21171   7.2500   NaN        S  New Value
# 1          PC 17599  71.2833   C85        C  New Value
# 2  STON/O2. 3101282   7.9250   NaN        S  New Value
# 3            113803  53.1000  C123        S  New Value
# ...

# %%
#copy columns

df['ek aur column'] = df['Pclass']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#              Ticket     Fare Cabin Embarked New Column  ek aur column
# 0         A/5 21171   7.2500   NaN        S  New Value              3
# 1          PC 17599  71.2833   C85        C  New Value              1
# 2  STON/O2. 3101282   7.9250   NaN        S  New Value              3
# ...

# %%
#get null data

df.isnull().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age              177
# SibSp              0
# Ticket             0
# Fare               0
# Cabin            687
# Embarked           2
# New Column         0
# ek aur column      0
# dtype: int64

# %%
#add values to null data

df.Age.fillna(df.Age.mean(), inplace=True)

# %%
#remove empty data

df.Embarked.dropna(inplace=True)
